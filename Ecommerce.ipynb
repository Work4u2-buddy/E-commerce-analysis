# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Ecommerce recommender using Support Vector Machine.csv")
print(df.head())
# Out:
#    Unnamed: 0 User_ID  Age  Gender  Location  Income   Interests  \
# 0           0      #1   56    Male  Suburban   38037      Sports
# 1           1      #2   46  Female     Rural  103986  Technology
# 2           2      #3   32  Female  Suburban  101942      Sports
# 3           3      #4   60  Female  Suburban   71612     Fashion
# 4           4      #5   25    Male  Suburban   49725      Travel
#
#    Last_Login_Days_Ago  Purchase_Frequency  Average_Order_Value  \
# 0                    5                   7                   18
# 1                   15                   7                  118
# 2                   28                   1                  146
# 3                   18                   3                  163
# 4                    2                   5                  141
#
#    Total_Spending Product_Category_Preference  Time_Spent_on_Site_Minutes  \
# 0            2546                       Books                         584
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   1000 non-null   int64
#  1   User_ID                      1000 non-null   object
#  2   Age                          1000 non-null   int64
#  3   Gender                       1000 non-null   object
#  4   Location                     1000 non-null   object
#  5   Income                       1000 non-null   int64
#  6   Interests                    1000 non-null   object
#  7   Last_Login_Days_Ago          1000 non-null   int64
#  8   Purchase_Frequency           1000 non-null   int64
#  9   Average_Order_Value          1000 non-null   int64
#  10  Total_Spending               1000 non-null   int64
#  11  Product_Category_Preference  1000 non-null   object
#  12  Time_Spent_on_Site_Minutes   1000 non-null   int64
# ...

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'User_ID', 'Age', 'Gender', 'Location', 'Income',
#        'Interests', 'Last_Login_Days_Ago', 'Purchase_Frequency',
#        'Average_Order_Value', 'Total_Spending', 'Product_Category_Preference',
#        'Time_Spent_on_Site_Minutes', 'Pages_Viewed',
#        'Newsletter_Subscription'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 15

# %% [markdown]
# <h2 style="font-size:26px; font-weight:bold; color:black;">
#  Check null values in the dataset
# </h2>

# %%
print(df.isnull())
# Out:
#      Unnamed: 0  User_ID    Age  Gender  Location  Income  Interests  \
# 0         False    False  False   False     False   False      False
# 1         False    False  False   False     False   False      False
# 2         False    False  False   False     False   False      False
# 3         False    False  False   False     False   False      False
# 4         False    False  False   False     False   False      False
# ..          ...      ...    ...     ...       ...     ...        ...
# 995       False    False  False   False     False   False      False
# 996       False    False  False   False     False   False      False
# 997       False    False  False   False     False   False      False
# 998       False    False  False   False     False   False      False
# 999       False    False  False   False     False   False      False
#
#      Last_Login_Days_Ago  Purchase_Frequency  Average_Order_Value  \
# 0                  False               False                False
# ...

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                     0
# User_ID                        0
# Age                            0
# Gender                         0
# Location                       0
# Income                         0
# Interests                      0
# Last_Login_Days_Ago            0
# Purchase_Frequency             0
# Average_Order_Value            0
# Total_Spending                 0
# Product_Category_Preference    0
# Time_Spent_on_Site_Minutes     0
# Pages_Viewed                   0
# Newsletter_Subscription        0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0 User_ID  Age  Gender  Location  Income   Interests  \
# 0           0      #1   56    Male  Suburban   38037      Sports
# 1           1      #2   46  Female     Rural  103986  Technology
# 2           2      #3   32  Female  Suburban  101942      Sports
# 3           3      #4   60  Female  Suburban   71612     Fashion
# 4           4      #5   25    Male  Suburban   49725      Travel
#
#    Last_Login_Days_Ago  Purchase_Frequency  Average_Order_Value  \
# 0                    5                   7                   18
# 1                   15                   7                  118
# 2                   28                   1                  146
# 3                   18                   3                  163
# 4                    2                   5                  141
#
#    Total_Spending Product_Category_Preference  Time_Spent_on_Site_Minutes  \
# 0            2546                       Books                         584
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# User_ID                        object
# Age                             int64
# Gender                         object
# Location                       object
# Income                          int64
# Interests                      object
# Last_Login_Days_Ago             int64
# Purchase_Frequency              int64
# Average_Order_Value             int64
# Total_Spending                  int64
# Product_Category_Preference    object
# Time_Spent_on_Site_Minutes      int64
# Pages_Viewed                    int64
# Newsletter_Subscription          bool
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   1000 non-null   int64
#  1   User_ID                      1000 non-null   object
#  2   Age                          1000 non-null   int64
#  3   Gender                       1000 non-null   object
#  4   Location                     1000 non-null   object
#  5   Income                       1000 non-null   int64
#  6   Interests                    1000 non-null   object
#  7   Last_Login_Days_Ago          1000 non-null   int64
#  8   Purchase_Frequency           1000 non-null   int64
#  9   Average_Order_Value          1000 non-null   int64
#  10  Total_Spending               1000 non-null   int64
#  11  Product_Category_Preference  1000 non-null   object
#  12  Time_Spent_on_Site_Minutes   1000 non-null   int64
# ...

# %%
#to know rows and  columns 
df.shape
# Out:
# (1000, 15)

# %%
#to convert all index , numpy etc in panda 
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'User_ID',
#  'Age',
#  'Gender',
#  'Location',
#  'Income',
#  'Interests',
#  'Last_Login_Days_Ago',
#  'Purchase_Frequency',
#  'Average_Order_Value',
#  'Total_Spending',
#  'Product_Category_Preference',
#  'Time_Spent_on_Site_Minutes',
#  'Pages_Viewed',
#  'Newsletter_Subscription']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'User_ID', 'Age', 'Gender', 'Location', 'Income',
#        'Interests', 'Last_Login_Days_Ago', 'Purchase_Frequency',
#        'Average_Order_Value', 'Total_Spending', 'Product_Category_Preference',
#        'Time_Spent_on_Site_Minutes', 'Pages_Viewed',
#        'Newsletter_Subscription'],
#       dtype='object')

# %% [markdown]
# <h2 style="font-size:26px; font-weight:bold; color:black;">
# Highest and Lowest Purchase Prices
# </h2>

# %%
# highest and lowest 'Total_Spending'
df['Total_Spending'].max()
# Out:
# np.int64(4999)

# %%
df['Total_Spending'].min()
# Out:
# np.int64(112)

# %%
df['Total_Spending'].mean()
# Out:
# np.float64(2552.957)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(df['Total_Spending'])
plt.show()

# %%
sns.scatterplot(x="Time_Spent_on_Site_Minutes", y="Total_Spending", data=df)
plt.suptitle("Total_Spending",fontsize=8)
plt.show()

# %% [markdown]
# <h2 style="font-size:26px; font-weight:bold; color:black;">
#                                Number of  'Pages_Viewed'
# </h2>

# %%
df['Pages_Viewed'].value_counts()
# Out:
# Pages_Viewed
# 29    32
# 16    30
# 26    28
# 19    28
# 10    28
# 6     28
# 7     27
# 31    26
# 43    25
# 35    25
# 37    24
# 2     24
# 48    24
# 13    24
# 4     24
# 41    24
# 42    23
# 17    23
# 44    22
# 25    22
# 33    21
# 23    21
# 12    21
# 24    20
# 36    20
# 47    20
# 22    19
# 8     19
# 18    19
# 1     19
# 15    18
# 28    18
# 9     18
# 5     17
# 32    17
# 3     17
# 45    16
# 39    16
# 40    15
# 21    15
# 27    15
# 30    15
# 11    15
# 38    14
# 20    14
# 34    14
# 46    13
# 14    12
# 49    11
# Name: count, dtype: int64

# %% [markdown]
# <h2 style="font-size:26px; font-weight:bold; color:black;">
# 'Time_Spent_on_Site_Minutes'
# </h2>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'User_ID', 'Age', 'Gender', 'Location', 'Income',
#        'Interests', 'Last_Login_Days_Ago', 'Purchase_Frequency',
#        'Average_Order_Value', 'Total_Spending', 'Product_Category_Preference',
#        'Time_Spent_on_Site_Minutes', 'Pages_Viewed',
#        'Newsletter_Subscription'],
#       dtype='object')

# %%
df[['Time_Spent_on_Site_Minutes']]
# Out:
#      Time_Spent_on_Site_Minutes
# 0                           584
# 1                           432
# 2                           306
# 3                           527
# 4                            53
# ..                          ...
# 995                         542
# 996                         359
# 997                         331
# 998                         427
# 999                         497
#
# [1000 rows x 1 columns]

# %%
plt.plot(df['Time_Spent_on_Site_Minutes'])
plt.show()

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'User_ID', 'Age', 'Gender', 'Location', 'Income',
#        'Interests', 'Last_Login_Days_Ago', 'Purchase_Frequency',
#        'Average_Order_Value', 'Total_Spending', 'Product_Category_Preference',
#        'Time_Spent_on_Site_Minutes', 'Pages_Viewed',
#        'Newsletter_Subscription'],
#       dtype='object')

# %% [markdown]
# <h2 style="font-size:26px; font-weight:bold; color:black;">
#     'Newsletter_Subscription'
# </h2>

# %%
df['Newsletter_Subscription'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: Newsletter_Subscription
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   bool
# dtypes: bool(1)
# memory usage: 1.1 KB

# %%
sns.barplot(x="Total_Spending", y="Newsletter_Subscription", data=df, estimator="mean", ci=None)
